# %% [markdown]
# # DALL-E 맛보기
#
# DALL-E (달리)는 이미지에 대한 설명을 입력으로 넣으면 이미지를 생성하는 모델

# %%
from dotenv import load_dotenv
load_dotenv(dotenv_path="../.env")
# Out:
# True

# %%
from openai import OpenAI
client = OpenAI()

response = client.images.generate(
    model="dall-e-3",
    prompt="a white siamese cat",
    size="1024x1024",
    quality="standard",
    n=1,
)

print(response.data[0].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-hVFoG7DI3G1uEXBa06E91IGR/user-9wkbinTpeywtTTkarLzoHXEi/img-J6XH3bgz95Ba0DrZfEIumJsS.png?st=2025-01-18T10%3A50%3A51Z&se=2025-01-18T12%3A50%3A51Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-18T00%3A17%3A52Z&ske=2025-01-19T00%3A17%3A52Z&sks=b&skv=2024-08-04&sig=ASatoL14Zy9K9vRtRnQ%2BbE%2BE836qBWXxgcQ0JhWMSQM%3D

# %%
gen_image_path = 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-hVFoG7DI3G1uEXBa06E91IGR/user-9wkbinTpeywtTTkarLzoHXEi/img-J6XH3bgz95Ba0DrZfEIumJsS.png?st=2025-01-18T10%3A50%3A51Z&se=2025-01-18T12%3A50%3A51Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-18T00%3A17%3A52Z&ske=2025-01-19T00%3A17%3A52Z&sks=b&skv=2024-08-04&sig=ASatoL14Zy9K9vRtRnQ%2BbE%2BE836qBWXxgcQ0JhWMSQM%3D'

import urllib
import matplotlib.pyplot as plt
from PIL import Image
img = Image.open(urllib.request.urlopen(gen_image_path))
 
# Plotting the image
plotimg = plt.imshow(img)

# %%
response = client.images.generate(
    model="dall-e-3",
    prompt="무엇이든 물어보세요. 귀엽고 친절한 첨단 고객센터 AI 로봇이에요. 이미지의 배경은 흰색입니다.",
    size="1024x1024",
    quality="standard",
    n=1,
)

print(response.data[0].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-hVFoG7DI3G1uEXBa06E91IGR/user-9wkbinTpeywtTTkarLzoHXEi/img-vKjD7ykHnl1rYEcRqeaWv88Z.png?st=2025-01-18T10%3A57%3A46Z&se=2025-01-18T12%3A57%3A46Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-18T00%3A38%3A20Z&ske=2025-01-19T00%3A38%3A20Z&sks=b&skv=2024-08-04&sig=0WyVIKvJGryXqDJ0CfBZ%2BN/VuBnLIb6/7ekYzSOHpHU%3D

# %%
gen_image_path = 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-hVFoG7DI3G1uEXBa06E91IGR/user-9wkbinTpeywtTTkarLzoHXEi/img-vKjD7ykHnl1rYEcRqeaWv88Z.png?st=2025-01-18T10%3A57%3A46Z&se=2025-01-18T12%3A57%3A46Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-18T00%3A38%3A20Z&ske=2025-01-19T00%3A38%3A20Z&sks=b&skv=2024-08-04&sig=0WyVIKvJGryXqDJ0CfBZ%2BN/VuBnLIb6/7ekYzSOHpHU%3D'

import urllib
import matplotlib.pyplot as plt
from PIL import Image
img = Image.open(urllib.request.urlopen(gen_image_path))
 
# Plotting the image
plotimg = plt.imshow(img)

# %%
response = client.images.generate(
    model="dall-e-3",
    prompt="반고흐 그림체로 하얀색 강아지가 숲에서 다른 동물들한테 열심히 설명하는 장면을 그려줘. 반고흐는 그리지 말아줘.",
    size="1024x1024",
    quality="standard",
    n=1,
    response_format='b64_json'
)

# print(response)
# ImagesResponse(created=1737201643, data=[Image(b64_json='...

import io
import base64
from IPython.display import display
image_data = base64.b64decode(response.data[0].b64_json)
image = Image.open(io.BytesIO(image_data))
image.save("image.png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
